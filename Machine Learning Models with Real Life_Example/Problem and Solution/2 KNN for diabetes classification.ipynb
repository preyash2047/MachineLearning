# %% [markdown]
# # Question:
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Answer:
# KNN is best suitable for these types of classification for various disease based on symptoms and features.

# %% [markdown]
# # K-Nearest Neighbors (K-NN)

# %% [markdown]
# ## Importing the libraries

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# ## Importing the dataset

# %%
dataset = pd.read_csv('dataset.csv')

# %% [markdown]
# ## Feature Selection

# %%
import seaborn as sns
sns.heatmap(dataset.corr())

# %% [markdown]
# Here light color represents the highest correlation whereas dark colour represents the lowers correlation, Based on the heatmap, we will select the relevant features.

# %%
X = dataset[['height', 'weight', 'wsa', 'income']].values
y = dataset[['target']].values

# %% [markdown]
# ## Splitting the dataset into the Training set and Test set

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25)

# %% [markdown]
# ## Feature Scaling

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %% [markdown]
# ## Training the K-NN model on the Training set

# %%
from sklearn.neighbors import KNeighborsClassifier
classifier = KNeighborsClassifier(n_neighbors = 5, metric = 'minkowski', p = 2)
classifier.fit(X_train, y_train)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:3: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   This is separate from the ipykernel package so we can avoid doing imports until
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#                      weights='uniform')

# %% [markdown]
# ##### Note: Minkowski Metric is used to apply euclidean distance

# %% [markdown]
# ## Predicting the Test set results

# %%
y_pred = classifier.predict(X_test)
print(np.concatenate((y_pred.reshape(len(y_pred),1), y_test.reshape(len(y_test),1)),1))
# Out:
# [[0 0]
#  [0 1]
#  [0 0]]

# %% [markdown]
# ## Making the Confusion Matrix

# %%
from sklearn.metrics import confusion_matrix, accuracy_score
cm = confusion_matrix(y_test, y_pred)
print(cm)
accuracy_score(y_test, y_pred)
# Out:
# [[2 0]
#  [1 0]]
# 0.6666666666666666

# %% [markdown]
# > # Conclusion
#
# > In this model I have used data of 1000 person in a certain community has diabetes based on a set of demographical characteristics
#
# > data terms:
# * height in meters
# * weight in grams
# * wsp: weekly sport activity in minutes
# * income in dollars
# * target - have diabetes or not (1=yes, 0=no)
#
# > Conclusion:
# K-Nearest Neighbors model has given the accuracy of XX%.
