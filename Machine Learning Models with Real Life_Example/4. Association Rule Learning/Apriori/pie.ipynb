# %% [markdown]
# ## Importing the libraries

# %%
#!pip install matplotlib

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# ## Data Preprocessing

# %%
dataset = pd.read_csv('DV_sample.csv')

# %%
dataset.head()
# Out:
#          Date  Apple  Huawei   Oppo  Xiaomi   Vivo  Mobicel   BBK  Samsung  \
# 0  10-01-2018  19.27   20.69  14.17    9.67  10.87     6.06   6.9     5.12
# 1  10-01-2018  20.27   21.69  15.17   10.67  11.87     7.06   7.9     6.12
# 2  12-01-2018  21.27   22.69  16.17   11.67  12.87     8.06   8.9     7.12
# 3  12-01-2018  22.27   23.69  17.17   12.67  13.87     9.06   9.9     8.12
# 4  14-01-2018  23.27   24.69  18.17   13.67  14.87    10.06  10.9     9.12
#
#    Meizu  ...  QMobile  Hisense  K-Touch  Asus  Konka  Vivo.1  Alcatel  \
# 0   2.03  ...     0.04     0.02     0.03  0.02   0.03    0.02     0.02
# 1   3.03  ...     1.04     1.02     1.03  1.02   1.03    1.02     1.02
# 2   4.03  ...     2.04     2.02     2.03  2.02   2.03    2.02     2.02
# 3   5.03  ...     3.04     3.02     3.03  3.02   3.03    3.02     3.02
# 4   6.03  ...     4.04     4.02     4.03  4.02   4.03    4.02     4.02
#
#    Infinix  Chine Mobile  Other
# 0     0.02          0.02   0.06
# 1     1.02          1.02   1.06
# 2     2.02          2.02   2.06
# 3     3.02          3.02   3.06
# 4     4.02          4.02   4.06
#
# [5 rows x 42 columns]

# %% [markdown]
# # Pie

# %%
del dataset["Date"]
data = np.array(dataset.sum())

# Creating autocpt arguments
def func(pct, allvalues):
    absolute = int(pct / 100.*np.sum(allvalues))
    return "{:.1f}%".format(pct, absolute)

# Creating plot
fig, ax = plt.subplots(figsize =(10, 7))
wedges, texts, autotexts = ax.pie(data, autopct = lambda pct: func(pct, data), labels = dataset.columns)
  
plt.setp(autotexts, size = 8)
plt.show()
